# %% [markdown]
# # Three Dimensional Force Systems

# %% [markdown]
# ## Beer & Johnston. *Vector Mechanics for Engineers: Statics*. Free-Body Practice Problem 2.F5, End-Of-Section Problems 2.101 - 2.102

# %% [markdown]
# Three cables are used to tether a balloon as shown.
#
# <br>
#
# ![bj-p2-f5-101-102.png](data:image/png;base64,...)

# %% [markdown]
# **P2.F5.** Knowing that the tension in cable *AC* is $ 444 \, \mathrm{N} $, draw the free-body diagram needed to determine the vertical force $ \mathbf{P} $ exerted by the balloon at *A*.
#
# <br>
#
# **P2.101.** Determine the vertical force $ \mathbf{P} $ exerted by the balloon at *A* knowing that the tension in cable *AD* is $ 481 \, \mathrm{N} $.
#
# <br>
#
# **P2.102.** Knowing that the balloon exerts an $ 800 \, \mathrm{N} $ force at *A*, determine the tension in each cable.

# %% [markdown]
# ## Hibbeler. *Engineering Mechanics: Statics*. Problems 2.122 - 2.123 - 2.124 (modified)

# %% [markdown]
# ![h-p2-122-123-124.png](data:image/png;base64,...)

# %% [markdown]
# The masses of the bars *AB*, *AC*, and *AD* are negligible. The force $ \mathbf{F} = \left( 600 \, \mathbf{\hat{i}} - 100 \, \mathbf{\hat{j}} + 600 \, \mathbf{\hat{k}} \right) \, \mathrm{N} $ acts on point *A*. The bars *AB* and *AC* exert forces at *A* that point toward *A* from *B* and *C*, respectively, whereas the bar *AD* exerts a force that points from *A* toward *D*. The *z* axis points upward. Determine the forces in the bars.

# %% [markdown]
# ## Bedford & Fowler. *Engineering Mechanics: Statics*. Problem 3.71

# %% [markdown]
# **Fig. a**
#
# <br>
#
# ![bf-p3_71a.png](data:image/png;base64,...)

# %% [markdown]
# **Fig. b**
#
# <br>
#
# ![bf-p3_71b.png](data:image/png;base64,...)

# %% [markdown]
# The car in Fig. *a* and the pallet supporting it weigh $ 3000 \, \mathrm{lb} $. They are supported by four cables *AB*, *AC*, *AD*, and *AE*. The locations of the attachment points on the pallet are shown in Fig. *b*. The tensions in cables *AB* and *AE* are equal. Determine the tensions in the cables.
