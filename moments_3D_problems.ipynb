# %% [markdown]
# # The Moment Vector

# %% [markdown]
# ## Meriam, Kraige & Bolton. *Engineering Mechanics: Statics*. Introductory Problem 2.94 (modified)

# %% [markdown]
# ![mk-ip2_94.png](data:image/png;base64,...)

# %% [markdown]
# The turnbuckle$^*$ is tightened until the tension in the cable *AB* equals $ 2.4 \, \mathrm{kN} $. Calculate the magnitude of the moment about point *O* of the force acting on point *A*.

# %% [markdown]
# **$^*$Turnbuckle:**
# <br>
# ![turnbuckle.png](data:image/png;base64,...)

# %% [markdown]
# ## Bedford & Fowler. *Engineering Mechanics: Statics*. Problems 4.69 - 4.70

# %% [markdown]
# The microwave transmission tower is $ 70 \, \mathrm{m} $ tall.
#
# <br>
#
# ![bf-p4_69-70.png](data:image/png;base64,...)

# %% [markdown]
# **P4.69**. The tensions in cables *AB*, *AC*, and *AD* are $ 4 \, \mathrm{kN} $, $ 2 \, \mathrm{kN} $, and $ 2 \, \mathrm{kN} $, respectively. Determine the sum of the moments about the origin *O* due to the forces exerted by the cables at point *A*.
#
# <br>
#
# **P4.70**. Suppose that the tension in cable AB is $ 4 \, \mathrm{kN} $, and you want to adjust the tensions in cables *AC* and *AD* so that the sum of the moments about the origin *O* due to the forces exerted by the cables at point *A* is zero. Determine the tensions.

# %% [markdown]
# ## Beer, Johnston *et al*. *Vector Mechanics for Engineers: Statics*. Problem 3.57 (modified, with image from Problems 2.85 - 2.86)

# %% [markdown]
# ![bj-p2_85-86-mod.png](data:image/png;base64,...)

# %% [markdown]
# The frame *ACD* is hinged at *A* and *D* and is supported by a cable that passes through a ring at *B* and is attached to hooks at *G* and *H*. $ \mathbf{P} $ represents a load with a magnitude $ \mathrm{P} = 200 \, \mathrm{N} $. Knowing that the tension in the cable is $ 450 \, \mathrm{N} $, determine the moment about point *A* of the forces exerted on the frame by portions *BG* and *BH* of the cable.

# %% [markdown]
# ## Bedford & Fowler. *Engineering Mechanics: Statics*. Problems 4.73 - 4.74

# %% [markdown]
# ![bf-p4_73-74.png](data:image/png;base64,...)

# %% [markdown]
# **P4.73**. The tension in the cable *BD* is $ 1 \, \mathrm{kN} $. As a result, cable *BD* exerts a $ 1 \, \mathrm{kN} $ force on the ball at *B* that points from *B* toward *D*. Determine the moment of this force about point *A*.
#
# <br>
#
# **P4.74**. Suppose that the mass of the suspended object *E* is $ 100 \, \mathrm{kg} $ and the mass of the bar *AB* is $ 20 \, \mathrm{kg} $. Assume that the weight of the bar acts at its midpoint. If the sum of the moments about point *A* due to the weight of the bar and the forces exerted on the ball at *B* by the three cables *BC*, *BD*, and *BE* is zero, determine the tensions in the cables *BC* and *BD*.

# %% [markdown]
# ## Meriam, Kraige & Bolton. *Engineering Mechanics: Statics*. Representative Problem 2.125 (modified)

# %% [markdown]
# ![mk-rp2_125.png](data:image/png;base64,...)

# %% [markdown]
# The tension in cable *AB* is $ 143,4 \, \mathrm{N} $. The mass of the uniform plate is $ 15 \, \mathrm{kg} $. Determine the moment of the tension force acting at *A* and of the weight $ \mathbf{W} $ about point *O*.
