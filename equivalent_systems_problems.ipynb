# %% [markdown]
# # Equivalent Systems

# %% [markdown]
# ## Hibbeler. *Engineering Mechanics: Statics*. Problems 4.99 - 4.100

# %% [markdown]
# ![h-p4_99-100.png](data:image/png;base64,...)

# %% [markdown]
# **P4.99** Replace the force system acting on the beam by an equivalent force and couple moment at point *A*.

# %% [markdown]
# **P4.100** Replace the force system acting on the beam by an equivalent force and couple moment at point *B*.

# %% [markdown]
# ## Bedford & Fowler. *Engineering Mechanics: Statics*. Problem 4.141

# %% [markdown]
# The vector sum of the forces acting on the beam is zero, and the sum of the moments about the left end of the beam is zero. <br>
# ![bf-p4_141.png](data:image/png;base64,...)

# %% [markdown]
# **(a)** Determine the forces $A_x$ and $A_y$, and the couple $M_A$.  <br>
# **(b)** Determine the sum of the moments about the right end of the beam. <br>
# **(c)** If you represent the $600 \mathrm{-N}$ force, the $200 \mathrm{-N}$ force, and the $30 \, \mathrm{N \cdot m}$ couple by a force **F** acting at the left end of the beam and a couple **M**, what are **F** and **M**?

# %% [markdown]
# ## Meriam, Kraige & Bolton. *Engineering Mechanics: Statics*. Representative Problem 2.65

# %% [markdown]
# ![couple-mk-rp2_65.png](data:image/png;base64,...)

# %% [markdown]
# The system consisting of the bar *OA*, two identical pulleys, and a section of thin tape is subjected to the two $180 \mathrm{-N}$ tensile forces shown in the figure. Determine the equivalent force–couple system at point *O*.

# %% [markdown]
# ## Hibbeler. *Engineering Mechanics: Statics*. Fundamental Problems 4.102 - 4.103

# %% [markdown]
# ![h-p4_102-103.png](data:image/png;base64,...)

# %% [markdown]
# **P4.102** Replace the loading system acting on the post by an equivalent resultant force and couple moment at point *A*. <br>
# **P4.103** Replace the loading system acting on the post by an equivalent resultant force and couple moment at point *B*.

# %% [markdown]
# ## Bedford & Fowler. *Engineering Mechanics: Statics*. Problem 4.144

# %% [markdown]
# ![bf-p4_144-145.png](data:image/png;base64,...)

# %% [markdown]
# At a particular instant, aerodynamic forces distributed over the airplane's surface exert the $88 \mathrm{-kN}$ and $16 \mathrm{-kN}$ vertical forces and the $22 \, \mathrm{kN \cdot m}$ counterclockwise couple shown. If you represent these forces and couple by a system consisting of a force **F** acting at the center of mass *G* and a couple *M*, what are **F** and *M*.

# %% [markdown]
# ## Meriam, Kraige & Bolton. *Engineering Mechanics: Statics*. Introductory Problem 2.76

# %% [markdown]
# ![mk-ip2_76.png](data:image/png;base64,...)

# %% [markdown]
# **(a)** Replace the forces acting on the crank by an equivalent force acting at *O*. <br>
# **(b)** If the resultant moment of the two forces about point *O* and the couple *M* is zero, determine *M*.

# %% [markdown]
# ## Bedford & Fowler. *Engineering Mechanics: Statics*. Problem 4.177

# %% [markdown]
# ![bf-p4_177.png](data:image/png;base64,...)

# %% [markdown]
# Three forces act on the structure. The sum of the moments due to the forces about *A* is zero. Determine the magnitude of the force *F*.

# %% [markdown]
# ## Meriam, Kraige & Bolton. *Engineering Mechanics: Statics*. Representative Problem 2.82

# %% [markdown]
# ![mk-rp2_82.png](data:image/png;base64,...)

# %% [markdown]
# A commercial airliner with four jet engines, each pro- ducing $90 \, \mathrm{kN}$ of forward thrust, is in a steady, level cruise when engine number 3 suddenly fails. Determine and locate the resultant of the three remaining engine thrust vectors. Treat this as a two-dimensional problem.

# %% [markdown]
# ## Bedford & Fowler. *Engineering Mechanics: Statics*. Problems 4.179 - 4.180

# %% [markdown]
# ![bf-p4_179-180.png](data:image/png;base64,...)

# %% [markdown]
# **P4.179** Determine the sum of the moments exerted about A by the three forces and the couple. <br>
# **P4.180** If you represent the three forces and the couple by an equivalent system consisting of a force **F** acting at *A* and a couple **M**, what are the magnitudes of **F** and **M**?

# %% [markdown]
# ## Meriam, Kraige & Bolton. *Engineering Mechanics: Statics*. Representative Problem 2.123

# %% [markdown]
# ![mk-rp2_123.png](data:image/png;base64,...)

# %% [markdown]
# A space shuttle orbiter is subjected to thrusts from five of the engines of its reaction control system. Four of the thrusts are shown in the figure; the fifth is an $850 \mathrm{-N}$ up-ward thrust at the right rear, symmetric to the $850 \mathrm{-N}$ thrust shown on the left rear. Compute the moment of these forces about point *G* and show that the forces have the same moment about all points.

# %% [markdown]
# ## Meriam, Kraige & Bolton. *Engineering Mechanics: Statics*. Representative Problem 2.136

# %% [markdown]
# ![mk-rp2_136.png](data:image/png;base64,...)

# %% [markdown]
# Represent the resultant of the force system acting on the pipe assembly by a single force **R** at *A* and a couple **M**.
